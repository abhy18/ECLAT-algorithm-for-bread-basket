# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/bread basket.csv')
df
# Out:
#        Transaction           Item         date_time period_day weekday_weekend
# 0                1          Bread  30-10-2016 09:58    morning         weekend
# 1                2   Scandinavian  30-10-2016 10:05    morning         weekend
# 2                2   Scandinavian  30-10-2016 10:05    morning         weekend
# 3                3  Hot chocolate  30-10-2016 10:07    morning         weekend
# 4                3            Jam  30-10-2016 10:07    morning         weekend
# ...            ...            ...               ...        ...             ...
# 20502         9682         Coffee  09-04-2017 14:32  afternoon         weekend
# 20503         9682            Tea  09-04-2017 14:32  afternoon         weekend
# 20504         9683         Coffee  09-04-2017 14:57  afternoon         weekend
# 20505         9683         Pastry  09-04-2017 14:57  afternoon         weekend
# 20506         9684      Smoothies  09-04-2017 15:04  afternoon         weekend
#
# ...

# %%
df.describe()
# Out:
#         Transaction
# count  20507.000000
# mean    4976.202370
# std     2796.203001
# min        1.000000
# 25%     2552.000000
# 50%     5137.000000
# 75%     7357.000000
# max     9684.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20507 entries, 0 to 20506
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction      20507 non-null  int64
#  1   Item             20507 non-null  object
#  2   date_time        20507 non-null  object
#  3   period_day       20507 non-null  object
#  4   weekday_weekend  20507 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 801.2+ KB

# %%
df.isnull().sum()
# Out:
# Transaction        0
# Item               0
# date_time          0
# period_day         0
# weekday_weekend    0
# dtype: int64

# %%
# !pip install pyECLAT

# %%
grped = df.groupby('Transaction')['Item'].apply(list).reset_index()
expand = grped['Item'].apply(pd.Series)
expand
# Out:
#                  0             1               2                 3    4    5   \
# 0             Bread           NaN             NaN               NaN  NaN  NaN
# 1      Scandinavian  Scandinavian             NaN               NaN  NaN  NaN
# 2     Hot chocolate           Jam         Cookies               NaN  NaN  NaN
# 3            Muffin           NaN             NaN               NaN  NaN  NaN
# 4            Coffee        Pastry           Bread               NaN  NaN  NaN
# ...             ...           ...             ...               ...  ...  ...
# 9460          Bread           NaN             NaN               NaN  NaN  NaN
# 9461       Truffles           Tea  Spanish Brunch  Christmas common  NaN  NaN
# 9462         Muffin  Tacos/Fajita          Coffee               Tea  NaN  NaN
# 9463         Coffee        Pastry             NaN               NaN  NaN  NaN
# 9464      Smoothies           NaN             NaN               NaN  NaN  NaN
#
#        6    7    8    9    10
# ...

# %%
from pyECLAT import ECLAT
ec = ECLAT(data=expand, verbose=True)
# Out:
# ...
# 100%|██████████| 94/94 [00:00<00:00, 1328.45it/s]

# %%
ec.uniq_
# Out:
# ['Scone',
#  'Half slice Monster ',
#  'Bacon',
#  'Argentina Night',
#  'Alfajores',
#  'Muesli',
#  'Focaccia',
#  'Tshirt',
#  'Christmas common',
#  'Afternoon with the baker',
#  'Chocolates',
#  'Caramel bites',
#  'Panatone',
#  'Raspberry shortbread sandwich',
#  'Eggs',
#  'Drinking chocolate spoons ',
#  'The Nomad',
#  'Pick and Mix Bowls',
#  'Gift voucher',
#  'Adjustment',
#  'Jammie Dodgers',
#  'Cherry me Dried fruit',
#  'Chimichurri Oil',
#  'Smoothies',
#  'Granola',
#  'Brownie',
#  'Polenta',
#  'Tea',
#  'Medialuna',
#  'Lemon and coconut',
#  "Ella's Kitchen Pouches",
#  'Tiffin',
#  'Olum & polenta',
#  'Kids biscuit',
#  'Bread',
#  'Brioche and salami',
#  'Cake',
#  'Baguette',
#  'Mighty Protein',
#  'Salad',
#  'Chicken Stew',
#  'Truffles',
#  'Tartine',
#  'Honey',
#  'Crepes',
#  'Basket',
#  'Duck egg',
#  'Muffin',
#  'The BART',
#  'Scandinavian',
#  'Mortimer',
#  'Bread Pudding',
#  'Bakewell',
#  'Bare Popcorn',
#  'Fairy Doors',
#  'Jam',
# ...

# %%
indexs , support = ec.fit(min_support=.02,min_combination=1,max_combination=3,separator = ' & ',verbose = True)
# Out:
# Combination 1 by 1
# 19it [00:00, 76.64it/s]
# Combination 2 by 2
# 171it [00:01, 134.33it/s]
# Combination 3 by 3
# 969it [00:08, 116.73it/s]

# %%
indexs
# Out:
# {'Scone': [2396,
#   2404,
#   2412,
#   2417,
#   2418,
#   2419,
#   2429,
#   2437,
#   2445,
#   2450,
#   2452,
#   2454,
#   2469,
#   2473,
#   2476,
#   2477,
#   2481,
#   2484,
#   2489,
#   2490,
#   2500,
#   2505,
#   2516,
#   2558,
#   2796,
#   2806,
#   2807,
#   2816,
#   2818,
#   2824,
#   2843,
#   2846,
#   2864,
#   2871,
#   2875,
#   2885,
#   2896,
#   2906,
#   2921,
#   3189,
#   3213,
#   3216,
#   3217,
#   3232,
#   3234,
#   3245,
#   3251,
#   3261,
#   3268,
#   3283,
#   3284,
#   3309,
#   3311,
#   3402,
#   3613,
#   3630,
#   3637,
#   3644,
#   3648,
#   3655,
#   3661,
#   3663,
#   3685,
#   3686,
#   3691,
#   3711,
#   3715,
#   3739,
#   3746,
#   4156,
#   4177,
#   4180,
#   4198,
#   4211,
#   4220,
#   4221,
#   4233,
#   4241,
#   4242,
#   4243,
#   4307,
#   4313,
#   4322,
#   4327,
#   4328,
#   4348,
#   4349,
#   4356,
#   4364,
#   4395,
#   4423,
#   4497,
#   4503,
#   4508,
#   4510,
#   4511,
#   4527,
#   4538,
#   4545,
# ...

# %%
support
# Out:
# {'Scone': 0.03454833597464342,
#  'Alfajores': 0.036344426835710514,
#  'Brownie': 0.04004226096143687,
#  'Tea': 0.14263074484944532,
#  'Medialuna': 0.061806656101426306,
#  'Bread': 0.32720549392498677,
#  'Cake': 0.10385631273111463,
#  'Truffles': 0.02028526148969889,
#  'Muffin': 0.03845747490755415,
#  'Scandinavian': 0.029054410987849975,
#  'Coffee': 0.47839408346539886,
#  'Farm House': 0.03919704173269942,
#  'Sandwich': 0.07184363444268357,
#  'Pastry': 0.0861067089276281,
#  'Hot chocolate': 0.05832012678288431,
#  'Cookies': 0.054410987849973586,
#  'Toast': 0.03359746434231379,
#  'Soup': 0.03444268357105124,
#  'Juice': 0.03856312731114633,
#  'Tea & Bread': 0.02810353935552034,
#  'Tea & Cake': 0.02377179080824089,
#  'Tea & Coffee': 0.049867934495509775,
#  'Medialuna & Coffee': 0.03518225039619651,
#  'Bread & Cake': 0.02334918119387216,
#  'Bread & Coffee': 0.09001584786053883,
#  'Bread & Pastry': 0.029160063391442156,
#  'Cake & Coffee': 0.054727945060750134,
# ...
